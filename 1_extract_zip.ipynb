# %% [markdown]
# # extraction des zip

# %%
import zipfile 
from pathlib import Path

# %%
zip_path = Path("C:\\Users\\chris\\traitement_images_semi_supervisées\\mri_dataset_brain_cancer_oc.zip")
extract_dir = Path("data")

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(extract_dir)

print("Extraction terminée !")
# Out:
# Extraction terminée !
